# %% [markdown]
# <a href="https://colab.research.google.com/github/somarathigaganasaisree/Certificates/blob/main/Week_3%2C4%2C5_MDS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-6407a665-264c-461c-b590-fb322fc28e90" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6407a665-264c-461c-b590-fb322fc28e90">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Simple_100_Student_Marks[1].csv")

# %%
df
# Out:
#             student_name  maths_marks  science_marks  english_marks  \
# 0   Mr. Gregory Homenick           69             24             52
# 1     Marlene Leffler IV           62             59             70
# 2        Josephine Ebert           29             76             13
# 3        Dr. Irene Green           44             66             14
# 4              Jake Huel           49             23             63
# ..                   ...          ...            ...            ...
# 95        Renee Schinner           69             99             73
# 96      Marguerite Ebert           32             62             82
# 97          Jorge Bednar           77             56             46
# 98   Mrs. Roxanne Jacobi           54             66             70
# 99       Dean Schowalter           28             49             78
#
#     social_studies_marks  language_marks
# 0                      4              83
# 1                     54              52
# ...

# %%
df.head(10)
# Out:
#            student_name  maths_marks  science_marks  english_marks  \
# 0  Mr. Gregory Homenick           69             24             52
# 1    Marlene Leffler IV           62             59             70
# 2       Josephine Ebert           29             76             13
# 3       Dr. Irene Green           44             66             14
# 4             Jake Huel           49             23             63
# 5        Ralph Schuster           69             28             55
# 6          Lila Schmidt           91             10             19
# 7         Ms. Naomi Rau           65             70             83
# 8     Maryann Marquardt           28             31             27
# 9              Edna Von           11             51             86
#
#    social_studies_marks  language_marks
# 0                     4              83
# 1                    54              52
# 2                     8              19
# 3                     2              14
# ...

# %%
df.tail(10)
# Out:
#             student_name  maths_marks  science_marks  english_marks  \
# 90         Amber Windler           88             50             49
# 91    Leticia Senger III           81             90             66
# 92   Mr. Patrick Mueller           81             81              5
# 93  Cedric Bergstrom Jr.           49             74             36
# 94        Elizabeth Ward           73             91             72
# 95        Renee Schinner           69             99             73
# 96      Marguerite Ebert           32             62             82
# 97          Jorge Bednar           77             56             46
# 98   Mrs. Roxanne Jacobi           54             66             70
# 99       Dean Schowalter           28             49             78
#
#     social_studies_marks  language_marks
# 90                    77              24
# 91                    15              21
# 92                    45              36
# 93                    57              66
# ...

# %%
print(df.shape)
print(df.index)
print(df.columns)
print(df.info())
# Out:
# (100, 6)
# RangeIndex(start=0, stop=100, step=1)
# Index(['student_name', 'maths_marks', 'science_marks', 'english_marks',
#        'social_studies_marks', 'language_marks'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_name          100 non-null    object
#  1   maths_marks           100 non-null    int64
#  2   science_marks         100 non-null    int64
#  3   english_marks         100 non-null    int64
#  4   social_studies_marks  100 non-null    int64
#  5   language_marks        100 non-null    int64
# dtypes: int64(5), object(1)
# memory usage: 4.8+ KB
# None

# %%
df[df['maths_marks'] > 50]
# Out:
#              student_name  maths_marks  science_marks  english_marks  \
# 0    Mr. Gregory Homenick           69             24             52
# 1      Marlene Leffler IV           62             59             70
# 5          Ralph Schuster           69             28             55
# 6            Lila Schmidt           91             10             19
# 7           Ms. Naomi Rau           65             70             83
# 10     Dr. Deborah Harvey           59             23             43
# 11  Mrs. Angie Schowalter           88             23             84
# 14    Armando Pollich PhD           91             64             38
# 15       Marvin Lehner MD           63             20             17
# 21         Edith Gorczany           60             48             94
# 23       Jonathon Ruecker           99             30              1
# 25        Monique Zboncak           88             48             22
# 26         Crystal Legros           66             53             42
# ...

# %%
df[['student_name', 'maths_marks']]
# Out:
#             student_name  maths_marks
# 0   Mr. Gregory Homenick           69
# 1     Marlene Leffler IV           62
# 2        Josephine Ebert           29
# 3        Dr. Irene Green           44
# 4              Jake Huel           49
# ..                   ...          ...
# 95        Renee Schinner           69
# 96      Marguerite Ebert           32
# 97          Jorge Bednar           77
# 98   Mrs. Roxanne Jacobi           54
# 99       Dean Schowalter           28
#
# [100 rows x 2 columns]

# %%
df.sort_values('maths_marks')
# Out:
#            student_name  maths_marks  science_marks  english_marks  \
# 12       Shirley Zulauf            2             60             94
# 58    Hubert Swaniawski            2              9             43
# 83      Eileen Ondricka            2              4             55
# 61            Bob Beier            4             40             20
# 18  Conrad Greenholt II            5             20             22
# ..                  ...          ...            ...            ...
# 38         John Schultz           97             11             52
# 67         Andres Lemke           97             78             64
# 23     Jonathon Ruecker           99             30              1
# 40       Marc Hermiston           99             94             38
# 45       Doyle Thompson          100             40             10
#
#     social_studies_marks  language_marks
# 12                    53              78
# 58                    24              70
# ...

# %%
df.describe()
# Out:
#        maths_marks  science_marks  english_marks  social_studies_marks  \
# count   100.000000     100.000000      100.00000            100.000000
# mean     48.950000      56.010000       52.48000             51.510000
# std      28.999956      26.487846       27.02542             29.081041
# min       2.000000       4.000000        1.00000              2.000000
# 25%      27.000000      39.500000       32.00000             29.250000
# 50%      52.500000      59.000000       51.00000             52.500000
# 75%      70.250000      76.000000       76.00000             77.000000
# max     100.000000      99.000000       97.00000            100.000000
#
#        language_marks
# count      100.000000
# mean        46.180000
# std         23.590522
# min          3.000000
# 25%         27.000000
# 50%         42.500000
# 75%         65.000000
# max         98.000000

# %%
df['student_name'].count()
# Out:
# np.int64(100)

# %%
df.rename(columns={'maths_marks': 'Maths'}, inplace=True)
